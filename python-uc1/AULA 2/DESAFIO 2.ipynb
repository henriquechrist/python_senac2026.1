# %% [markdown]
# #Desafio Python

# %%
nome=input("Qual é seu nome? ")
print("Seu nome é", nome)
# Out:
# Seu nome é Jorge

# %%
ano=input("Qual ano você nasceu? ")
print("Você nasceu em :",ano)
# Out:
# Você nasceu em : 1979

# %%
AnoOG=int(ano)
Idade=2026-AnoOG
print(f"{nome}, sua idade aproximada é de {Idade} anos.")
# Out:
# Jorge, sua idade aproximada é de 47 anos.
