# %% [markdown]
# # AULA 03 - 14-08-2026

# %% [markdown]
# ## Primeiros códigos e jupyter

# %%
print("olá, mundo!")
# Out:
# olá, mundo!

# %% [markdown]
# ## Tipos de Variáveis

# %%
numero=15
numero_fracionario=15,2
numero_fracionario_float=15.2
texto="Papagaio"

# %%
type(numero)
# Out:
# int

# %%
type(numero_fracionario)
# Out:
# tuple

# %%
type(texto)
# Out:
# str

# %% [markdown]
# ### AQUI COMO A CÉLULA POSSUI APENAS UM OUTPUT AI USAMOS O PRINT

# %%
print(type(numero))
print(type(numero_fracionario))
print(type(texto))
print(type(numero_fracionario_float))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'str'>
# <class 'float'>

# %%
texto.upper()
# Out:
# 'PAPAGAIO'

# %%
texto.lower()
# Out:
# 'papagaio'

# %% [markdown]
# ## Exercícios

# %%
exercicio1= print(numero+numero_fracionario_float)
# Out:
# 30.2

# %%
exercicio1=(numero+numero_fracionario_float)

# %%
print(type(exercicio1))
# Out:
# <class 'float'>

# %%
print(str(numero)+texto)
# Out:
# 15Papagaio

# %%
texto2= texto + " " + texto

# %%
print(texto2)
# Out:
# Papagaio Papagaio

# %%
idade= input("digite sua idade:")

# %%
type(idade)
# Out:
# str

# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.

# %%
idade_numero= int(idade)

# %%
type(idade_numero)
# Out:
# int

# %%
idade_numero_2=int(input("Qual é sua idade?"))

# %%
type(idade_numero_2)
# Out:
# int

# %%
print(idade_numero)
print(idade_numero_2)
# Out:
# 24
# 25

# %%
print("Olá meu nome é Henrique, tenho ",idade_numero_2,"anos")
# Out:
# Olá meu nome é Henrique, tenho  25 anos
