# %% [markdown]
# ## AULA 8

# %%
def saudacao(display='sem nome'):
    print(f"ola, {display}!!!")

# %%
saudacao("papagaio")
# Out:
# ola, papagaio!!!

# %% [markdown]
# ## Passagem de argumentos arbitrario

# %%
def saudacoes(*nomes): #*Varios argumentos
     print(nomes)

# %%
saudacoes('Henrique', 'Adriano', 'Gloria')
# Out:
# ('Henrique', 'Adriano', 'Gloria')

# %% [markdown]
# # MODULOS

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
from math import sqrt

print(sqrt(25))
# Out:
# 5.0

# %%
raiz=sqrt

print(sqrt(25))
# Out:
# 5.0

# %%
import mymodule

mymodule.saudacao("ze da manga")
# Out:
# Olá, ze da manga
