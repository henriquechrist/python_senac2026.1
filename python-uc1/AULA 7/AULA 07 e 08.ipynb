# %% [markdown]
# # Aula 07 e 08 - 24/08/2026

# %% [markdown]
# ## Teste de Mesa

# %%
a= 5    # primeira variável
b=10    # segunda variável
soma= (a+b)     # Variável de soma
print(soma)     # Output
# Out:
# 15

# %% [markdown]
# ## Utilizando Funções

# %% [markdown]
# ### Tratam-se de blocos de códigos

# %%
def nome_da_funcao (parametros):
    #bloco de codigo
    return resultado

# %%
def soma (a,b):
    soma=a+b
    print(f"Sua soma é: {soma}")
    return soma

# %%
resultado=soma(12,15)
# Out:
# Sua soma é: 27

# %%
def potencia (numero,expoente):
    resultado = numero**expoente
    print(f"O resultado da potência é: {resultado}")
    return potencia

# %%
rr=potencia(50,10)
# Out:
# O resultado da potência é: 97656250000000000

# %%
n1= 4
n2= 2
print(potencia(numero=n1,expoente=n2))
# Out:
# O resultado da potência é: 16
# <function potencia at 0x000002E76A3BE5C0>
