# %% [markdown]
# # AULA 11

# %%
d1 = {}
d2 = dict()

telefones ={"Alice":"1234-5678","Bob":"8765-4321"}
print(telefones)
# Out:
# {'Alice': '1234-5678', 'Bob': '8765-4321'}

# %%
d3 = dict(nome="Carlos", idade=25)
print(d3)
# Out:
# {'nome': 'Carlos', 'idade': 25}

# %%
listas_tuplas=[("a",1),("b",2)]
d4 = dict(listas_tuplas)
print(d4)
# Out:
# {'a': 1, 'b': 2}

# %%
chaves = ["nome","idade","cidade"]
valor_padrao="N/A"
usuario = dict.fromkeys(chaves,valor_padrao)
print(usuario)

usuario["nome"]="Kiel"
usuario["idade"]=10000000
usuario["cidade"]="Petropolis"
usuario["nascimento"]=1250
print(chaves)
print(usuario)
# Out:
# {'nome': 'N/A', 'idade': 'N/A', 'cidade': 'N/A'}
# ['nome', 'idade', 'cidade']
# {'nome': 'Kiel', 'idade': 10000000, 'cidade': 'Petropolis', 'nascimento': 1250}
