# %% [markdown]
# # AULA 04 - 17-08-2026

# %%
meu_livro = "Python para Iniciantes"
print(meu_livro)
# Out:
# Python para Iniciantes

# %%
meu_livro = "Algoritimos Divertidos"
print(meu_livro)
# Out:
# Algoritimos Divertidos

# %%
PI= 3.14159
GRAVIDADE = 9,8

# %%
type (GRAVIDADE)
# Out:
# tuple

# %%
print(GRAVIDADE[0])
# Out:
# 9

# %% [markdown]
# ## Tipos de dados

# %%
inteiro=10
ponto_flutuante=3.14
numero_complexo= 2+3j

# %%
print(type(inteiro))
print(type(ponto_flutuante))
print(type(numero_complexo))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# ## Quebra de Linhas

# %%
multilinha="""Oi,
Cara,
Beleza?"""
print(multilinha)
# Out:
# Oi,
# Cara,
# Beleza?

# %% [markdown]
# ## Tuplas e Listas

# %%
tupla=(1,2)
type(tupla)
# Out:
# tuple

# %%
print(tupla[1])
# Out:
# 2

# %%
lista=[1,2]
type(lista)
# Out:
# list

# %%
lista[1]=3

# %%
print(lista)
# Out:
# [1, 3]

# %%
lista.append(4)

# %%
print(lista)
# Out:
# [1, 3, 4]

# %%
lista=list(range(1,10,2))
print(lista)
# Out:
# [1, 3, 5, 7, 9]
